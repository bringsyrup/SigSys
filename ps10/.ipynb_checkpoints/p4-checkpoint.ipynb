# %%
# %matplotlib inline
# %run convenience.ipynb
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

np.set_printoptions(precision=2,suppress=True) # numpy output options

pi=np.pi
j=1j

# %% [markdown]
# ### Problem 4!

# %% [markdown]
# ### A). $H(s) = \frac{1}{s^2 - 0.01s + 1}$

# %%
combinedplot(signal.lti([1],[1, -.01, 1]))#Be careful to specify a time or frequency range if needed.
#For example, those strange beats in the step response DO NOT EXIST. They are an illusion.

# %% [markdown]
# ### B). $H(s) = \frac{K_p}{s^2 - 0.01s + 1 + K_p}$

# %%
Kp = 1
combinedplot(signal.lti([Kp],[1, -0.01, 1+Kp]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %%
Kp = -2
combinedplot(signal.lti([Kp],[1, -0.01, 1+Kp]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %%
Kp = 1000
combinedplot(signal.lti([Kp],[1, -0.01, 1+Kp]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %% [markdown]
# ### C). $H(s) = \frac{K_p}{s^3 - 0.01s^2 + s + K_p}$

# %%
Kp = 1
combinedplot(signal.lti([Kp],[1, -.01, 1, Kp]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %%
Kp = -1
combinedplot(signal.lti([Kp],[1, -.01, 1, Kp]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %%
Kp = .1
combinedplot(signal.lti([Kp],[1, -.01, 1, Kp]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %%
Kp = -20
combinedplot(signal.lti([Kp],[1, -.01, 1, Kp]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %% [markdown]
# ### D). $H(s) = \frac{K_p}{s^2 + (K_p - 0.01)s + 1}$

# %%
Kp = 1
combinedplot(signal.lti([Kp],[1, Kp-.01, 1]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %%
Kp = -1
combinedplot(signal.lti([Kp],[1, Kp-.01, 1]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %%
Kp = 1000
combinedplot(signal.lti([Kp],[1, Kp-.01, 1]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')

# %%
Kp = .1
combinedplot(signal.lti([Kp],[1, Kp-.01, 1]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')
